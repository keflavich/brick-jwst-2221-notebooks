# %%
# %run -i /orange/adamginsburg/jwst/brick/analysis/make_icecolumn_fig9b_f212n.py
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# icemol=CO, molwt=28.010145 u, mol_wt_tgtmol=28.010145 u, comps=[1], mols=['CO'], massfrac=1.0
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# icemol=CO, molwt=21.552516153846152 u, mol_wt_tgtmol=28.010145 u, comps=[5.0, 1.0, 0.5], mols=['H2O', 'CO', 'CO2'], massfrac=0.15384615384615385
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# icemol=H2O, molwt=21.552516153846152 u, mol_wt_tgtmol=18.015287 u, comps=[5.0, 1.0, 0.5], mols=['H2O', 'CO', 'CO2'], massfrac=0.7692307692307693
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# icemol=CO, molwt=18.923910454545453 u, mol_wt_tgtmol=28.010145 u, comps=[10.0, 1.0], mols=['H2O', 'CO'], massfrac=0.09090909090909091
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# icemol=H2O, molwt=18.923910454545453 u, mol_wt_tgtmol=18.015287 u, comps=[10.0, 1.0], mols=['H2O', 'CO'], massfrac=0.9090909090909091
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# icemol=CO, molwt=22.783239615384616 u, mol_wt_tgtmol=28.010145 u, comps=[10.0, 1.0, 2.0], mols=['H2O', 'CO', 'CO2'], massfrac=0.07692307692307693
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# icemol=H2O, molwt=22.783239615384616 u, mol_wt_tgtmol=18.015287 u, comps=[10.0, 1.0, 2.0], mols=['H2O', 'CO', 'CO2'], massfrac=0.7692307692307693
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# icemol=CO, molwt=20.5140015 u, mol_wt_tgtmol=28.010145 u, comps=[3.0, 1.0], mols=['H2O', 'CO'], massfrac=0.25
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# icemol=CO, molwt=20.5140015 u, mol_wt_tgtmol=28.010145 u, comps=[3.0, 1.0], mols=['H2O', 'CO'], massfrac=0.25
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# icemol=CO, molwt=20.5140015 u, mol_wt_tgtmol=28.010145 u, comps=[3.0, 1.0], mols=['H2O', 'CO'], massfrac=0.25
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# icemol=CO, molwt=20.5140015 u, mol_wt_tgtmol=28.010145 u, comps=[3.0, 1.0], mols=['H2O', 'CO'], massfrac=0.25
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# icemol=CO, molwt=20.5140015 u, mol_wt_tgtmol=28.010145 u, comps=[3.0, 1.0], mols=['H2O', 'CO'], massfrac=0.25
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# icemol=CO, molwt=20.5140015 u, mol_wt_tgtmol=28.010145 u, comps=[3.0, 1.0], mols=['H2O', 'CO'], massfrac=0.25
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# icemol=CO, molwt=20.5140015 u, mol_wt_tgtmol=28.010145 u, comps=[3.0, 1.0], mols=['H2O', 'CO'], massfrac=0.25
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# icemol=H2O, molwt=18.015287 u, mol_wt_tgtmol=18.015287 u, comps=[1.0], mols=['H2O'], massfrac=1.0
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# icemol=CO, molwt=34.59813529411765 u, mol_wt_tgtmol=28.010145 u, comps=[100.0, 70.0], mols=['CO', 'CO2'], massfrac=0.5882352941176471

# %%
dmag_tbl = Table.read(f'{basepath}/tables/H2O+CO_ice_absorption_tables.ecsv')
dmag_tbl.add_index('composition')

comp = 'H2O:CO (3:1)'
dmag_tbl.loc[comp]

av, cocol = makeplot(avfilts=['F182M', 'F212N'], sel=ok2221, ok=ok2221, ax=pl.figure().gca(),
         icemol='CO', abundance=1e-4,
         title=comp,
         dereddened=True,
         dmag_tbl=dmag_tbl.loc[comp])
makeplot(avfilts=['F182M', 'F212N'], sel=ok2221, ok=ok2221, ax=pl.figure().gca(),
         icemol='H2O', abundance=10**-3.31,
         title=comp,
         dmag_tbl=dmag_tbl.loc[comp]);
Table([av, cocol], names=['A_V', 'N(CO)']).write('/orange/adamginsburg/jwst/brick/catalogs/ForBrandt_20250320_usingF212N.ecsv')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# icemol=CO, molwt=20.5140015 u, mol_wt_tgtmol=28.010145 u, comps=[3.0, 1.0], mols=['H2O', 'CO'], massfrac=0.25
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# icemol=H2O, molwt=20.5140015 u, mol_wt_tgtmol=18.015287 u, comps=[3.0, 1.0], mols=['H2O', 'CO'], massfrac=0.75
