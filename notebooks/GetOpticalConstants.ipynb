# %%
import requests

# %%
resp = requests.get('https://ocdb.smce.nasa.gov/dataset/89/download-data/all')
resp
# Out:
# <Response [200]>

# %%
from astropy.table import Table
from astropy.io import ascii

# %%
ascii.read(resp.text, format='csv', delimiter='\t', header_start=5, data_start=6)
# Out:
# <Table length=54>
# Wavelength (µm) Wavenumber (cm⁻¹)    n          k       col4   _1  Wavelength (µm)_1 Wavenumber (cm⁻¹)_1    T
#     float64          float64      float64    float64   int64 int64      float64            float64       float64
# --------------- ----------------- -------- ----------- ----- ----- ----------------- ------------------- -------
#        4.750594            2105.0   1.4151 0.000236189    --    --          4.750594              2105.0 100.014
#        4.739336            2110.0  1.43413 0.000240087    --    --          4.739336              2110.0 100.014
#        4.728132            2115.0  1.46094 0.000217997    --    --          4.728132              2115.0 100.014
#        4.716981            2120.0  1.50183 0.000131507    --    --          4.716981              2120.0 100.014
#        4.711425            2122.5  1.53159 2.90404e-05    --    --          4.711425              2122.5 100.014
# ...

# %%
ascii.read(resp.text, format='csv', delimiter='\t', header_start=5, data_start=6)
# Out:
# <Table length=54>
# Wavelength (µm) Wavenumber (cm⁻¹)    n          k       col4   _1  Wavelength (µm)_1 Wavenumber (cm⁻¹)_1    T
#     float64          float64      float64    float64   int64 int64      float64            float64       float64
# --------------- ----------------- -------- ----------- ----- ----- ----------------- ------------------- -------
#        4.750594            2105.0   1.4151 0.000236189    --    --          4.750594              2105.0 100.014
#        4.739336            2110.0  1.43413 0.000240087    --    --          4.739336              2110.0 100.014
#        4.728132            2115.0  1.46094 0.000217997    --    --          4.728132              2115.0 100.014
#        4.716981            2120.0  1.50183 0.000131507    --    --          4.716981              2120.0 100.014
#        4.711425            2122.5  1.53159 2.90404e-05    --    --          4.711425              2122.5 100.014
# ...

# %%
ascii.read(resp.text.encode('ascii', 'ignore').decode(), format='csv', delimiter='\t', header_start=5, data_start=6)
# Out:
# <Table length=54>
# Wavelength (m) Wavenumber (cm)    n          k      Wavelength (m)_1 Wavenumber (cm)_1    T
#    float64         float64     float64    float64       float64           float64      float64
# -------------- --------------- -------- ----------- ---------------- ----------------- -------
#       4.750594          2105.0   1.4151 0.000236189         4.750594            2105.0 100.014
#       4.739336          2110.0  1.43413 0.000240087         4.739336            2110.0 100.014
#       4.728132          2115.0  1.46094 0.000217997         4.728132            2115.0 100.014
#       4.716981          2120.0  1.50183 0.000131507         4.716981            2120.0 100.014
#       4.711425          2122.5  1.53159 2.90404e-05         4.711425            2122.5 100.014
#       4.705882          2125.0  1.57256         0.0         4.705882            2125.0 100.014
#       4.700353          2127.5  1.63409         0.0         4.700353            2127.5 100.014
# ...

# %%
S = requests.Session()
resp1 = S.get('https://ocdb.smce.nasa.gov/search/ice')
resp = S.get('https://ocdb.smce.nasa.gov/ajax/datatable',
             params={'start':0, 'length': 220,
                   'search[value]': '',
                   'search[regex]': 'false',
                   'form_data[0][name]': 'formula_type',
                   'form_data[0][value]': 'ice',
                   'form_data[1][name]': 'temperature-min',
                   'form_data[1][value]': '',
                   'form_data[2][name]': 'temperature-max',
                   'form_data[2][value]': '',
                   'form_data[3][name]': 'wave-type-selector',
                   'form_data[3][value]': 'wavenumber',
                   'form_data[4][name]': 'wavenumber-min',
                   'form_data[4][value]': '',
                   'form_data[5][name]': 'wavenumber-max',
                   'form_data[5][value]': '',
                   'form_data[6][name]': 'wavelength-min',
                   'form_data[6][value]': '',
                   'form_data[7][name]': 'wavelength-max',
                   'form_data[7][value]': '',
                   "columns[0][data]": "formula_components",
                   "columns[0][name]": "",
                   "columns[0][searchable]": "true",
                   "columns[0][orderable]": "true",
                   "columns[0][search][value]": "",
                   "columns[0][search][regex]": "false",
                   "columns[1][data]": "formula_ratio",
                   "columns[1][name]": "",
                   "columns[1][searchable]": "true",
                   "columns[1][orderable]": "true",
                   "columns[1][search][value]": "",
                   "columns[1][search][regex]": "false",
                   "columns[2][data]": "dataset_temperature",
                   "columns[2][name]": "",
                   "columns[2][searchable]": "true",
                   "columns[2][orderable]": "true",
                   "columns[2][search][value]": "",
                   "columns[2][search][regex]": "false",
                   "columns[3][data]": "wavenumber_min",
                   "columns[3][name]": "",
                   "columns[3][searchable]": "true",
                   "columns[3][orderable]": "true",
                   "columns[3][search][value]": "",
                   "columns[3][search][regex]": "false",
                   "columns[4][data]": "wavenumber_max",
                   "columns[4][name]": "",
                   "columns[4][searchable]": "true",
                   "columns[4][orderable]": "true",
                   "columns[4][search][value]": "",
                   "columns[4][search][regex]": "false",
                   "columns[5][data]": "chart",
                   "columns[5][name]": "",
                   "columns[5][searchable]": "true",
                   "columns[5][orderable]": "true",
                   "columns[5][search][value]": "",
                   "columns[5][search][regex]": "false",
                   "columns[6][data]": "n",
                   "columns[6][name]": "",
                   "columns[6][searchable]": "true",
                   "columns[6][orderable]": "true",
                   "columns[6][search][value]": "",
                   "columns[6][search][regex]": "false",
                   "columns[7][data]": "k",
                   "columns[7][name]": "",
                   "columns[7][searchable]": "true",
                   "columns[7][orderable]": "true",
                   "columns[7][search][value]": "",
                   "columns[7][search][regex]": "false",
                   "columns[8][data]": "t",
                   "columns[8][name]": "",
                   "columns[8][searchable]": "true",
                   "columns[8][orderable]": "true",
                   "columns[8][search][value]": "",
                   "columns[8][search][regex]": "false",
                   "columns[9][data]": "r",
                   "columns[9][name]": "",
                   "columns[9][searchable]": "true",
                   "columns[9][orderable]": "true",
                   "columns[9][search][value]": "",
                   "columns[9][search][regex]": "false",
                   "columns[10][data]": "a",
                   "columns[10][name]": "",
                   "columns[10][searchable]": "true",
                   "columns[10][orderable]": "true",
                   "columns[10][search][value]": "",
                   "columns[10][search][regex]": "false",
                   "columns[11][data]": "o",
                   "columns[11][name]": "",
                   "columns[11][searchable]": "true",
                   "columns[11][orderable]": "true",
                   "columns[11][search][value]": "",
                   "columns[11][search][regex]": "false",
                   "columns[12][data]": "reference",
                   "columns[12][name]": "",
                   "columns[12][searchable]": "true",
                   "columns[12][orderable]": "true",
                   "columns[12][search][value]": "",
                   "columns[12][search][regex]": "false",
                   "order[0][column]": "0",
                   "order[0][dir]": "asc",
                   'draw': '1',
                   #"_":"1684519032387",
                  }
            )
resp
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup

# %%
metadata = resp.json()
soups = [BeautifulSoup(x['formula_components']) for x in metadata['data']]
molecules = {soup.find('a').text: soup.find('a').attrs['href'] for soup in soups}

# %%
resp.json()
# Out:
# {'draw': 1,
#  'recordsTotal': 88,
#  'recordsFiltered': 88,
#  'data': [{'formula_components': '<a href="https://ocdb.smce.nasa.gov/dataset/90">CH3COCH3</a>',
#    'formula_ratio': '1',
#    'dataset_temperature': '10K',
#    'wavenumber_min': 499.96,
#    'wavenumber_max': 3600.02,
#    'chart': '<img class="ocdb-thumb-chart-img" data-dataset_id="90" src="https://ocdb.smce.nasa.gov/assets/images/thumb-charts/90-wavenumber.png">',
#    'n': '&#10003;',
#    'k': '&#10003;',
#    't': '-',
#    'r': '-',
#    'a': '&#10003;',
#    'o': '-',
#    'reference': 'Hudson et al. (2018)'},
#   {'formula_components': '<a href="https://ocdb.smce.nasa.gov/dataset/91">CH3COCH3</a>',
#    'formula_ratio': '1',
#    'dataset_temperature': '125K',
#    'wavenumber_min': 499.96,
#    'wavenumber_max': 3600.02,
#    'chart': '<img class="ocdb-thumb-chart-img" data-dataset_id="91" src="https://ocdb.smce.nasa.gov/assets/images/thumb-charts/91-wavenumber.png">',
#    'n': '&#10003;',
# ...

# %%
molecules
# Out:
# {'CH3COCH3': 'https://ocdb.smce.nasa.gov/dataset/91',
#  'CH3OH': 'https://ocdb.smce.nasa.gov/dataset/41',
#  'CH4': 'https://ocdb.smce.nasa.gov/dataset/93',
#  'CO': 'https://ocdb.smce.nasa.gov/dataset/89',
#  'CO:CH4': 'https://ocdb.smce.nasa.gov/dataset/4',
#  'CO:OCS': 'https://ocdb.smce.nasa.gov/dataset/8',
#  'CO2': 'https://ocdb.smce.nasa.gov/dataset/97',
#  'CO2:CH4': 'https://ocdb.smce.nasa.gov/dataset/53',
#  'CO2:OCS': 'https://ocdb.smce.nasa.gov/dataset/56',
#  'H2O': 'https://ocdb.smce.nasa.gov/dataset/79',
#  'H2O:CH3OH:CO:NH3': 'https://ocdb.smce.nasa.gov/dataset/28',
#  'H2O:CH4': 'https://ocdb.smce.nasa.gov/dataset/62',
#  'H2O:OCS': 'https://ocdb.smce.nasa.gov/dataset/67',
#  'N2:CH4': 'https://ocdb.smce.nasa.gov/dataset/13',
#  'N2:OCS': 'https://ocdb.smce.nasa.gov/dataset/17',
#  'N2O': 'https://ocdb.smce.nasa.gov/dataset/99',
#  'O2:CH4': 'https://ocdb.smce.nasa.gov/dataset/20',
#  'O2:OCS': 'https://ocdb.smce.nasa.gov/dataset/22',
# ...

# %%
molname = 'OCS'
soups = [BeautifulSoup(x['formula_components'], 'html5') for x in metadata['data']]
molecules = {soup.find('a').text: soup.find('a').attrs['href'] for soup in soups}

dtabresp = S.get(f'{molecules[molname]}/download-data/all')
ascii.read(dtabresp.text.encode('ascii', 'ignore').decode(), format='csv', delimiter='\t', header_start=5, data_start=6)
# Out:
# <Table length=2592>
# Wavelength (m) Wavenumber (cm)    n        k      Wavelength (m)_1 Wavenumber (cm)_1    T
#    float64         float64     float64  float64       float64           float64      float64
# -------------- --------------- ------- ---------- ---------------- ----------------- -------
#       14.28143          700.21  1.2749 0.00037597         16.65584            600.39    99.9
#      14.261673          701.18  1.2744  0.0084278        16.629251            601.35   100.0
#      14.242174          702.14  1.2712  0.0084048        16.615988            601.83    99.9
#      14.222728           703.1  1.2683  0.0083846         16.58925             602.8    99.9
#      14.203133          704.07  1.2696 0.00032383        16.562873            603.76    99.9
#      14.183794          705.03  1.2709  0.0083697        16.536305            604.73   100.0
#      14.164306           706.0  1.2676  0.0083489        16.510096            605.69   100.0
# ...

# %%
requests.get('https://ocdb.smce.nasa.gov/ajax/datatable?draw=5&columns%5B0%5D%5Bdata%5D=formula_components&columns%5B0%5D%5Bname%5D=&columns%5B0%5D%5Bsearchable%5D=true&columns%5B0%5D%5Borderable%5D=true&columns%5B0%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B0%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B1%5D%5Bdata%5D=formula_ratio&columns%5B1%5D%5Bname%5D=&columns%5B1%5D%5Bsearchable%5D=true&columns%5B1%5D%5Borderable%5D=true&columns%5B1%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B1%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B2%5D%5Bdata%5D=dataset_temperature&columns%5B2%5D%5Bname%5D=&columns%5B2%5D%5Bsearchable%5D=true&columns%5B2%5D%5Borderable%5D=true&columns%5B2%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B2%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B3%5D%5Bdata%5D=wavenumber_min&columns%5B3%5D%5Bname%5D=&columns%5B3%5D%5Bsearchable%5D=true&columns%5B3%5D%5Borderable%5D=true&columns%5B3%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B3%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B4%5D%5Bdata%5D=wavenumber_max&columns%5B4%5D%5Bname%5D=&columns%5B4%5D%5Bsearchable%5D=true&columns%5B4%5D%5Borderable%5D=true&columns%5B4%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B4%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B5%5D%5Bdata%5D=chart&columns%5B5%5D%5Bname%5D=&columns%5B5%5D%5Bsearchable%5D=true&columns%5B5%5D%5Borderable%5D=true&columns%5B5%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B5%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B6%5D%5Bdata%5D=n&columns%5B6%5D%5Bname%5D=&columns%5B6%5D%5Bsearchable%5D=true&columns%5B6%5D%5Borderable%5D=true&columns%5B6%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B6%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B7%5D%5Bdata%5D=k&columns%5B7%5D%5Bname%5D=&columns%5B7%5D%5Bsearchable%5D=true&columns%5B7%5D%5Borderable%5D=true&columns%5B7%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B7%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B8%5D%5Bdata%5D=t&columns%5B8%5D%5Bname%5D=&columns%5B8%5D%5Bsearchable%5D=true&columns%5B8%5D%5Borderable%5D=true&columns%5B8%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B8%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B9%5D%5Bdata%5D=r&columns%5B9%5D%5Bname%5D=&columns%5B9%5D%5Bsearchable%5D=true&columns%5B9%5D%5Borderable%5D=true&columns%5B9%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B9%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B10%5D%5Bdata%5D=a&columns%5B10%5D%5Bname%5D=&columns%5B10%5D%5Bsearchable%5D=true&columns%5B10%5D%5Borderable%5D=true&columns%5B10%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B10%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B11%5D%5Bdata%5D=o&columns%5B11%5D%5Bname%5D=&columns%5B11%5D%5Bsearchable%5D=true&columns%5B11%5D%5Borderable%5D=true&columns%5B11%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B11%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B12%5D%5Bdata%5D=reference&columns%5B12%5D%5Bname%5D=&columns%5B12%5D%5Bsearchable%5D=true&columns%5B12%5D%5Borderable%5D=true&columns%5B12%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B12%5D%5Bsearch%5D%5Bregex%5D=false&order%5B0%5D%5Bcolumn%5D=0&order%5B0%5D%5Bdir%5D=asc&start=0&length=220&search%5Bvalue%5D=&search%5Bregex%5D=false&form_data%5B0%5D%5Bname%5D=formula_type&form_data%5B0%5D%5Bvalue%5D=ice&form_data%5B1%5D%5Bname%5D=components&form_data%5B1%5D%5Bvalue%5D=H2O&form_data%5B2%5D%5Bname%5D=components&form_data%5B2%5D%5Bvalue%5D=CO&form_data%5B3%5D%5Bname%5D=temperature-min&form_data%5B3%5D%5Bvalue%5D=&form_data%5B4%5D%5Bname%5D=temperature-max&form_data%5B4%5D%5Bvalue%5D=&form_data%5B5%5D%5Bname%5D=wave-type-selector&form_data%5B5%5D%5Bvalue%5D=wavenumber&form_data%5B6%5D%5Bname%5D=wavenumber-min&form_data%5B6%5D%5Bvalue%5D=&form_data%5B7%5D%5Bname%5D=wavenumber-max&form_data%5B7%5D%5Bvalue%5D=&form_data%5B8%5D%5Bname%5D=wavelength-min&form_data%5B8%5D%5Bvalue%5D=&form_data%5B9%5D%5Bname%5D=wavelength-max&form_data%5B9%5D%5Bvalue%5D=&_=1684519032387')
# Out:
# <Response [200]>

# %%
print("https://ocdb.smce.nasa.gov/ajax/datatable?draw=5&columns%5B0%5D%5Bdata%5D=formula_components&columns%5B0%5D%5Bname%5D=&columns%5B0%5D%5Bsearchable%5D=true&columns%5B0%5D%5Borderable%5D=true&columns%5B0%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B0%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B1%5D%5Bdata%5D=formula_ratio&columns%5B1%5D%5Bname%5D=&columns%5B1%5D%5Bsearchable%5D=true&columns%5B1%5D%5Borderable%5D=true&columns%5B1%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B1%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B2%5D%5Bdata%5D=dataset_temperature&columns%5B2%5D%5Bname%5D=&columns%5B2%5D%5Bsearchable%5D=true&columns%5B2%5D%5Borderable%5D=true&columns%5B2%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B2%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B3%5D%5Bdata%5D=wavenumber_min&columns%5B3%5D%5Bname%5D=&columns%5B3%5D%5Bsearchable%5D=true&columns%5B3%5D%5Borderable%5D=true&columns%5B3%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B3%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B4%5D%5Bdata%5D=wavenumber_max&columns%5B4%5D%5Bname%5D=&columns%5B4%5D%5Bsearchable%5D=true&columns%5B4%5D%5Borderable%5D=true&columns%5B4%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B4%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B5%5D%5Bdata%5D=chart&columns%5B5%5D%5Bname%5D=&columns%5B5%5D%5Bsearchable%5D=true&columns%5B5%5D%5Borderable%5D=true&columns%5B5%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B5%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B6%5D%5Bdata%5D=n&columns%5B6%5D%5Bname%5D=&columns%5B6%5D%5Bsearchable%5D=true&columns%5B6%5D%5Borderable%5D=true&columns%5B6%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B6%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B7%5D%5Bdata%5D=k&columns%5B7%5D%5Bname%5D=&columns%5B7%5D%5Bsearchable%5D=true&columns%5B7%5D%5Borderable%5D=true&columns%5B7%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B7%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B8%5D%5Bdata%5D=t&columns%5B8%5D%5Bname%5D=&columns%5B8%5D%5Bsearchable%5D=true&columns%5B8%5D%5Borderable%5D=true&columns%5B8%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B8%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B9%5D%5Bdata%5D=r&columns%5B9%5D%5Bname%5D=&columns%5B9%5D%5Bsearchable%5D=true&columns%5B9%5D%5Borderable%5D=true&columns%5B9%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B9%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B10%5D%5Bdata%5D=a&columns%5B10%5D%5Bname%5D=&columns%5B10%5D%5Bsearchable%5D=true&columns%5B10%5D%5Borderable%5D=true&columns%5B10%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B10%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B11%5D%5Bdata%5D=o&columns%5B11%5D%5Bname%5D=&columns%5B11%5D%5Bsearchable%5D=true&columns%5B11%5D%5Borderable%5D=true&columns%5B11%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B11%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B12%5D%5Bdata%5D=reference&columns%5B12%5D%5Bname%5D=&columns%5B12%5D%5Bsearchable%5D=true&columns%5B12%5D%5Borderable%5D=true&columns%5B12%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B12%5D%5Bsearch%5D%5Bregex%5D=false&order%5B0%5D%5Bcolumn%5D=0&order%5B0%5D%5Bdir%5D=asc&start=0&length=220&search%5Bvalue%5D=&search%5Bregex%5D=false&form_data%5B0%5D%5Bname%5D=formula_type&form_data%5B0%5D%5Bvalue%5D=ice&form_data%5B1%5D%5Bname%5D=components&form_data%5B1%5D%5Bvalue%5D=H2O&form_data%5B2%5D%5Bname%5D=components&form_data%5B2%5D%5Bvalue%5D=CO&form_data%5B3%5D%5Bname%5D=temperature-min&form_data%5B3%5D%5Bvalue%5D=&form_data%5B4%5D%5Bname%5D=temperature-max&form_data%5B4%5D%5Bvalue%5D=&form_data%5B5%5D%5Bname%5D=wave-type-selector&form_data%5B5%5D%5Bvalue%5D=wavenumber&form_data%5B6%5D%5Bname%5D=wavenumber-min&form_data%5B6%5D%5Bvalue%5D=&form_data%5B7%5D%5Bname%5D=wavenumber-max&form_data%5B7%5D%5Bvalue%5D=&form_data%5B8%5D%5Bname%5D=wavelength-min&form_data%5B8%5D%5Bvalue%5D=&form_data%5B9%5D%5Bname%5D=wavelength-max&form_data%5B9%5D%5Bvalue%5D=&_=1684519032387")
# Out:
# https://ocdb.smce.nasa.gov/ajax/datatable?draw=5&columns%5B0%5D%5Bdata%5D=formula_components&columns%5B0%5D%5Bname%5D=&columns%5B0%5D%5Bsearchable%5D=true&columns%5B0%5D%5Borderable%5D=true&columns%5B0%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B0%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B1%5D%5Bdata%5D=formula_ratio&columns%5B1%5D%5Bname%5D=&columns%5B1%5D%5Bsearchable%5D=true&columns%5B1%5D%5Borderable%5D=true&columns%5B1%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B1%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B2%5D%5Bdata%5D=dataset_temperature&columns%5B2%5D%5Bname%5D=&columns%5B2%5D%5Bsearchable%5D=true&columns%5B2%5D%5Borderable%5D=true&columns%5B2%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B2%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B3%5D%5Bdata%5D=wavenumber_min&columns%5B3%5D%5Bname%5D=&columns%5B3%5D%5Bsearchable%5D=true&columns%5B3%5D%5Borderable%5D=true&columns%5B3%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B3%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B4%5D%5Bdata%5D=wavenumber_max&columns%5B4%5D%5Bname
# ...

# %%
resp.request.body
# Out:
# 'start=0&length=220&search%5Bvalue%5D=&search%5Bregex%5D=false&form_data%5B0%5D%5Bname%5D=formula_type&form_data%5B0%5D%5Bvalue%5D=ice&form_data%5B1%5D%5Bname%5D=components&form_data%5B1%5D%5Bvalue%5D=H2O&form_data%5B2%5D%5Bname%5D=components&form_data%5B2%5D%5Bvalue%5D=CO&form_data%5B3%5D%5Bname%5D=temperature-min&form_data%5B3%5D%5Bvalue%5D=&form_data%5B4%5D%5Bname%5D=temperature-max&form_data%5B4%5D%5Bvalue%5D=&form_data%5B5%5D%5Bname%5D=wave-type-selector&form_data%5B5%5D%5Bvalue%5D=wavenumber&form_data%5B6%5D%5Bname%5D=wavenumber-min&form_data%5B6%5D%5Bvalue%5D=&form_data%5B7%5D%5Bname%5D=wavenumber-max&form_data%5B7%5D%5Bvalue%5D=&form_data%5B8%5D%5Bname%5D=wavelength-min&form_data%5B8%5D%5Bvalue%5D=&form_data%5B9%5D%5Bname%5D=wavelength-max&form_data%5B9%5D%5Bvalue%5D=&columns%5B0%5D%5Bdata%5D=formula_components&columns%5B0%5D%5Bname%5D=&columns%5B0%5D%5Bsearchable%5D=true&columns%5B0%5D%5Borderable%5D=true&columns%5B0%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B0%5D%5Bsearch%5D%5Bre
# ...

# %%
order[0][column]: 0
order[0][dir]: asc
start: 0
length: 220
search[value]: 
search[regex]: false
form_data[0][name]: formula_type
form_data[0][value]: ice
form_data[1][name]: components
form_data[1][value]: H2O
form_data[2][name]: components
form_data[2][value]: CO
form_data[3][name]: temperature-min
form_data[3][value]: 
form_data[4][name]: temperature-max
form_data[4][value]: 
form_data[5][name]: wave-type-selector
form_data[5][value]: wavenumber
form_data[6][name]: wavenumber-min
form_data[6][value]: 
form_data[7][name]: wavenumber-max
form_data[7][value]: 
form_data[8][name]: wavelength-min
form_data[8][value]: 
form_data[9][name]: wavelength-max
form_data[9][value]:

# %%
resp
# Out:
# 'Internal Server Error'

# %%
columns[0][data]: formula_components
columns[0][name]: 
columns[0][searchable]: true
columns[0][orderable]: true
columns[0][search][value]: 
columns[0][search][regex]: false
columns[1][data]: formula_ratio
columns[1][name]: 
columns[1][searchable]: true
columns[1][orderable]: true
columns[1][search][value]: 
columns[1][search][regex]: false
columns[2][data]: dataset_temperature
columns[2][name]: 
columns[2][searchable]: true
columns[2][orderable]: true
columns[2][search][value]: 
columns[2][search][regex]: false
columns[3][data]: wavenumber_min
columns[3][name]: 
columns[3][searchable]: true
columns[3][orderable]: true
columns[3][search][value]: 
columns[3][search][regex]: false
columns[4][data]: wavenumber_max
columns[4][name]: 
columns[4][searchable]: true
columns[4][orderable]: true
columns[4][search][value]: 
columns[4][search][regex]: false
columns[5][data]: chart
columns[5][name]: 
columns[5][searchable]: true
columns[5][orderable]: true
columns[5][search][value]: 
columns[5][search][regex]: false
columns[6][data]: n
columns[6][name]: 
columns[6][searchable]: true
columns[6][orderable]: true
columns[6][search][value]: 
columns[6][search][regex]: false
columns[7][data]: k
columns[7][name]: 
columns[7][searchable]: true
columns[7][orderable]: true
columns[7][search][value]: 
columns[7][search][regex]: false
columns[8][data]: t
columns[8][name]: 
columns[8][searchable]: true
columns[8][orderable]: true
columns[8][search][value]: 
columns[8][search][regex]: false
columns[9][data]: r
columns[9][name]: 
columns[9][searchable]: true
columns[9][orderable]: true
columns[9][search][value]: 
columns[9][search][regex]: false
columns[10][data]: a
columns[10][name]: 
columns[10][searchable]: true
columns[10][orderable]: true
columns[10][search][value]: 
columns[10][search][regex]: false
columns[11][data]: o
columns[11][name]: 
columns[11][searchable]: true
columns[11][orderable]: true
columns[11][search][value]: 
columns[11][search][regex]: false
columns[12][data]: reference
columns[12][name]: 
columns[12][searchable]: true
columns[12][orderable]: true
columns[12][search][value]: 
columns[12][search][regex]: false
order[0][column]: 0
order[0][dir]: asc
start: 0
length: 220
search[value]: 
search[regex]: false
form_data[0][name]: formula_type
form_data[0][value]: ice
form_data[1][name]: components
form_data[1][value]: H2O
form_data[2][name]: components
form_data[2][value]: CO
form_data[3][name]: temperature-min
form_data[3][value]: 
form_data[4][name]: temperature-max
form_data[4][value]: 
form_data[5][name]: wave-type-selector
form_data[5][value]: wavenumber
form_data[6][name]: wavenumber-min
form_data[6][value]: 
form_data[7][name]: wavenumber-max
form_data[7][value]: 
form_data[8][name]: wavelength-min
form_data[8][value]: 
form_data[9][name]: wavelength-max
form_data[9][value]:

# %%
import requests

# %%
resp = requests.get('http://www1.univap.br/gaa/nkabs-database/G1.txt', headers={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36'})
ascii.read(resp.text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /scratch/local/64463386/ipykernel_41430/787468327.py in <module>
#       1 resp = requests.get('http://www1.univap.br/gaa/nkabs-database/G1.txt', headers={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36'})
# ----> 2 ascii.read(resp.text)
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'read'

# %%
resp.text
# Out:
# 'Description: CO (10K)\n      freq [cm-1]   absorbance      imag pt (k)       real pt (n)\n---------------------------------------------------------------------\n       2001.6200  -0.00013497800  -0.00036200000       1.3094960\n       2002.1100  -0.00011865700  -0.00031900000       1.3098350\n       2002.5900  -8.7149400e-05  -0.00023200000       1.3098350\n       2003.0700  -8.0672100e-05  -0.00021600000       1.3099090\n       2003.5500  -9.2224200e-05  -0.00024300000       1.3098950\n       2004.0400  -0.00010273000  -0.00027300000       1.3100080\n       2004.5200  -0.00010115000  -0.00026700000       1.3100500\n       2005.0000  -9.6491500e-05  -0.00025500000       1.3101530\n       2005.4800  -9.1766900e-05  -0.00024700000       1.3101740\n       2005.9600  -8.7975500e-05  -0.00023800000       1.3102790\n       2006.4500  -8.1634100e-05  -0.00021300000       1.3102980\n       2006.9300  -6.9113400e-05  -0.00018700000       1.3103780\n       2007.4100  -6.5508300e-05  -0.0001780
# ...

# %%
resp = requests.get('http://www1.univap.br/gaa/nkabs-database/G1.txt')
ascii.read(resp.text, header_start=1, data_start=3)
