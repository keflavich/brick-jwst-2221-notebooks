# %%
import sys
sys.path.append("/Users/adam/work/brick/jwst/brick-jwst-2221/analysis")
sys.path.append("/Users/adam/work/brick/jwst/brick-jwst-2221/reduction")

# %%
pwd
# Out:
# '/Users/adam/work/brick/jwst/brick-jwst-2221/notebooks'

# %%
from paths import basepath

# %%
# %run $basepath/analysis/selections.py --module=merged1182
# Out:
# /Users/adam/work/brick/jwst/brick-jwst-2221/analysis/selections.py:23: DeprecationWarning: `photutils.CircularAperture` is a deprecated alias for `photutils.aperture.CircularAperture` and will be removed in the future. Instead, please use `from photutils.aperture import CircularAperture` to silence this warning.
#   from photutils import CircularAperture, EPSFBuilder, find_peaks, CircularAnnulus
# /Users/adam/work/brick/jwst/brick-jwst-2221/analysis/selections.py:23: DeprecationWarning: `photutils.EPSFBuilder` is a deprecated alias for `photutils.psf.EPSFBuilder` and will be removed in the future. Instead, please use `from photutils.psf import EPSFBuilder` to silence this warning.
#   from photutils import CircularAperture, EPSFBuilder, find_peaks, CircularAnnulus
# /Users/adam/work/brick/jwst/brick-jwst-2221/analysis/selections.py:23: DeprecationWarning: `photutils.find_peaks` is a deprecated alias for `photutils.detection.find_peaks` and will be removed in the future. Instead, please use `from photutils.detection import find_peaks` to silence this warning.
#   from photutils import CircularAperture, EPSFBuilder, find_peaks, CircularAnnulus
# /Users/adam/work/brick/jwst/brick-jwst-2221/analysis/selections.py:23: DeprecationWarning: `photutils.CircularAnnulus` is a deprecated alias for `photutils.aperture.CircularAnnulus` and will be removed in the future. Instead, please use `from photutils.aperture import CircularAnnulus` to silence this warning.
#   from photutils import CircularAperture, EPSFBuilder, find_peaks, CircularAnnulus
# Selecting module merged1182
#
# merged-reproject
# 760 saturated in near_saturated_f212n_f212n
# 53 saturated in near_saturated_f466n_f466n
# 241 saturated in near_saturated_f405n_f405n
# 444 saturated in near_saturated_f187n_f187n
# 4876 saturated in near_saturated_f182m_f182m
# 7361 near saturated out of 487201.  That leaves 479840 not near unsaturated
# 88 saturated in replaced_saturated_f212n
# 13 saturated in replaced_saturated_f466n
# 52 saturated in replaced_saturated_f405n
# 34 saturated in replaced_saturated_f187n
# 338 saturated in replaced_saturated_f182m
# 539 saturated out of 487201.  That leaves 486662 unsaturated
# Filter f410m has qf=140561, spread=140845, fracflux=102909 ok, totaling 102342.  There are 487201 total, of which 353504 are masked and 133697 are unmasked. qfmasksum=344533, inverse=142668.
# Filter f212n has qf=310359, spread=312169, fracflux=236464 ok, totaling 236077.  There are 487201 total, of which 178334 are masked and 308867 are unmasked. qfmasksum=173856, inverse=313345.
# Filter f466n has qf=108575, spread=109245, fracflux=79985 ok, totaling 79629.  There are 487201 total, of which 381020 are masked and 106181 are unmasked. qfmasksum=377032, inverse=110169.
# Filter f405n has qf=118244, spread=118840, fracflux=85478 ok, totaling 85128.  There are 487201 total, of which 373321 are masked and 113880 are unmasked. qfmasksum=367129, inverse=120072.
# Filter f187n has qf=262180, spread=264481, fracflux=214357 ok, totaling 213894.  There are 487201 total, of which 225092 are masked and 262109 are unmasked. qfmasksum=222118, inverse=265083.
# Filter f182m has qf=439630, spread=441160, fracflux=338185 ok, totaling 337561.  There are 487201 total, of which 55364 are masked and 431837 are unmasked. qfmasksum=44203, inverse=442998.
# Of 487201 rows, 58840 are good in all filters.
# Of 487201 rows, 61850 are good in long filters.
# Of 487201 rows, 177204 are good in short filters.
# Of 487201 rows, 377235 are good in at least one filter.
# QFs: 230575 good short
# QFs: 81491 good long
# Found 72303 of 487201 sources with separations < 0.1 arcsec
# Offset between raw ABmag for F410M-F466N = -3.100931445988974 - -3.40491784270845 = 0.303986396719476
# Possible BrA excess (405-410 < -1): 757, (405-410 < -0.5): 3041.
# Very likely BrA+PaA excess (405-410 < -0.1 and 187-182 < -0.1): 14792, <-0.5: 165.
# Pretty blue [410-466] sources: 1660
# Pretty blue 405-466] sources: 1196
# Very blue [410-466] sources: 90
# Very blue 405-466] sources: 59
# Somewhat blue 405-466] sources: 7377
# 65093 1660 7377 757 3041 14792 87766 0.16853906979923888
# Negative 405-410 colors: 24970, Nonnegative: 80213
# There are 58276 before flagging out any_saturated (there are 8736 any_saturated)
# There are 57901 after flagging out any_saturated
# There are 72303 out of 487201 oksep, and 56144 all_good & oksep
# Excluding 424353 of 487201
# 'Bad' sources are those where _any_ filter is masked out
# Not-bad:56144, bad: 431057, len(bad):487201, len(table):487201.
#
# merged
# 1387 saturated in near_saturated_f212n_f212n
# 136 saturated in near_saturated_f466n_f466n
# 852 saturated in near_saturated_f405n_f405n
# 638 saturated in near_saturated_f187n_f187n
# 7116 saturated in near_saturated_f182m_f182m
# 8623 near saturated out of 1226028.  That leaves 1217405 not near unsaturated
# 55 saturated in replaced_saturated_f212n
# 18 saturated in replaced_saturated_f466n
# 78 saturated in replaced_saturated_f405n
# 29 saturated in replaced_saturated_f187n
# 472 saturated in replaced_saturated_f182m
# 564 saturated out of 1226028.  That leaves 1225464 unsaturated
# Filter f410m has qf=144004, spread=127613, fracflux=14117 ok, totaling 13938.  There are 1226028 total, of which 1103816 are masked and 122212 are unmasked. qfmasksum=1081696, inverse=144332.
# Filter f212n has qf=473141, spread=473203, fracflux=267384 ok, totaling 267317.  There are 1226028 total, of which 753383 are masked and 472645 are unmasked. qfmasksum=752556, inverse=473472.
# Filter f466n has qf=329582, spread=329547, fracflux=73254 ok, totaling 73218.  There are 1226028 total, of which 896640 are masked and 329388 are unmasked. qfmasksum=896384, inverse=329644.
# Filter f405n has qf=387979, spread=387902, fracflux=57098 ok, totaling 57077.  There are 1226028 total, of which 838482 are masked and 387546 are unmasked. qfmasksum=837999, inverse=388029.
# Filter f187n has qf=388261, spread=388375, fracflux=251005 ok, totaling 250953.  There are 1226028 total, of which 837747 are masked and 388281 are unmasked. qfmasksum=837609, inverse=388419.
# Filter f182m has qf=512209, spread=379194, fracflux=112233 ok, totaling 98523.  There are 1226028 total, of which 902542 are masked and 323486 are unmasked. qfmasksum=710939, inverse=515089.
# Of 1226028 rows, 1756 are good in all filters.
# Of 1226028 rows, 2486 are good in long filters.
# Of 1226028 rows, 54925 are good in short filters.
# Of 1226028 rows, 365717 are good in at least one filter.
# QFs: 318553 good short
# QFs: 72007 good long
# Found 173540 of 1226028 sources with separations < 0.1 arcsec
# Offset between raw ABmag for F410M-F466N = -3.100931445988974 - -3.40491784270845 = 0.303986396719476
# Possible BrA excess (405-410 < -1): 1929, (405-410 < -0.5): 4032.
# Very likely BrA+PaA excess (405-410 < -0.1 and 187-182 < -0.1): 0, <-0.5: 0.
# Pretty blue [410-466] sources: 33061
# Pretty blue 405-466] sources: 32232
# Very blue [410-466] sources: 18280
# Very blue 405-466] sources: 17735
# Somewhat blue 405-466] sources: 17174
# 23977 33061 17174 1929 4032 0 53036 0.0
# Negative 405-410 colors: 61050, Nonnegative: 20861
# There are 1442 before flagging out any_saturated (there are 19329 any_saturated)
# There are 1434 after flagging out any_saturated
# There are 173540 out of 1226028 oksep, and 1434 all_good & oksep
# Excluding 1203248 of 1226028
# 'Bad' sources are those where _any_ filter is masked out
# Not-bad:1434, bad: 1224594, len(bad):1226028, len(table):1226028.
#
# merged1182
# 1387 saturated in near_saturated_f212n_f212n
# 136 saturated in near_saturated_f466n_f466n
# 852 saturated in near_saturated_f405n_f405n
# 638 saturated in near_saturated_f187n_f187n
# 7116 saturated in near_saturated_f182m_f182m
# 8623 near saturated out of 1226028.  That leaves 1217405 not near unsaturated
# 55 saturated in replaced_saturated_f212n
# 18 saturated in replaced_saturated_f466n
# 78 saturated in replaced_saturated_f405n
# 29 saturated in replaced_saturated_f187n
# 472 saturated in replaced_saturated_f182m
# 564 saturated out of 1226028.  That leaves 1225464 unsaturated
# Filter f410m has qf=144004, spread=127613, fracflux=14117 ok, totaling 13938.  There are 1226028 total, of which 1103816 are masked and 122212 are unmasked. qfmasksum=1081696, inverse=144332.
# Filter f212n has qf=473141, spread=473203, fracflux=267384 ok, totaling 267317.  There are 1226028 total, of which 753383 are masked and 472645 are unmasked. qfmasksum=752556, inverse=473472.
# Filter f466n has qf=329582, spread=329547, fracflux=73254 ok, totaling 73218.  There are 1226028 total, of which 896640 are masked and 329388 are unmasked. qfmasksum=896384, inverse=329644.
# Filter f405n has qf=387979, spread=387902, fracflux=57098 ok, totaling 57077.  There are 1226028 total, of which 838482 are masked and 387546 are unmasked. qfmasksum=837999, inverse=388029.
# Filter f187n has qf=388261, spread=388375, fracflux=251005 ok, totaling 250953.  There are 1226028 total, of which 837747 are masked and 388281 are unmasked. qfmasksum=837609, inverse=388419.
# Filter f182m has qf=512209, spread=379194, fracflux=112233 ok, totaling 98523.  There are 1226028 total, of which 902542 are masked and 323486 are unmasked. qfmasksum=710939, inverse=515089.
# Of 1226028 rows, 1756 are good in all filters.
# Of 1226028 rows, 2486 are good in long filters.
# Of 1226028 rows, 54925 are good in short filters.
# Of 1226028 rows, 365717 are good in at least one filter.
# QFs: 318553 good short
# QFs: 72007 good long
# Found 173540 of 1226028 sources with separations < 0.1 arcsec
# Offset between raw ABmag for F410M-F466N = -3.100931445988974 - -3.40491784270845 = 0.303986396719476
# Possible BrA excess (405-410 < -1): 1929, (405-410 < -0.5): 4032.
# Very likely BrA+PaA excess (405-410 < -0.1 and 187-182 < -0.1): 0, <-0.5: 0.
# Pretty blue [410-466] sources: 33061
# Pretty blue 405-466] sources: 32232
# Very blue [410-466] sources: 18280
# Very blue 405-466] sources: 17735
# Somewhat blue 405-466] sources: 17174
# 23977 33061 17174 1929 4032 0 53036 0.0
# Negative 405-410 colors: 61050, Nonnegative: 20861
# There are 1442 before flagging out any_saturated (there are 19329 any_saturated)
# There are 1434 after flagging out any_saturated
# There are 173540 out of 1226028 oksep, and 1434 all_good & oksep
# Excluding 1203248 of 1226028
# 'Bad' sources are those where _any_ filter is masked out
# Not-bad:1434, bad: 1224594, len(bad):1226028, len(table):1226028.
# Loaded merged1182

# %%
(blue_405_410 & long_good).sum()
# Out:
# 0

# %%
pl.figure(figsize=(20,10))
ax = pl.subplot(2,1,1, adjustable='box', aspect=0.88)

crds = basetable['skycoord_f410m']
sel = basetable['sep_f405n'].quantity < 0.1*u.arcsec
sel &= (~any_saturated) & (any_good)
#sel &= basetable['mag_ab_f410m'] < 18.5
sel &= blue_405_410b
xx,yy = ww410.world_to_pixel(crds[sel])

colorby = basetable['mag_ab_f182m'] - basetable['mag_ab_f410m']
colorby = basetable['mag_ab_f410m']

colornorm = simple_norm(colorby[sel], stretch='linear')
cmap = 'YlOrRd'

scat = ax.scatter(
                  crds.dec[sel],
                  crds.ra[sel],
                  c=colorby[sel],
                  s=3.5,
                  alpha=0.75,
                  norm=colornorm,
                  cmap=cmap)

pl.draw()
colors = scat.get_facecolors()
scat.set_edgecolors(colors)
scat.set_facecolors('none')
ax.axis()
ax.set_ylabel("Right Ascension [ICRS]")
ax.set_xlabel("Declination [ICRS]");

# %%
sc = pl.scatter((basetable['mag_ab_f405n'] - basetable['mag_ab_f444w'])[sel],
                (basetable['mag_ab_f405n'])[sel],
                 s=2.5, alpha=0.75,
                 marker='.',
                 #c=colorby[sel],
                 #norm=colornorm, cmap=cmap
                )
pl.ylim(pl.ylim()[::-1])
# Out:
# (16.272535848617554, 8.256985139846801)

# %%
pl.figure(figsize=(20,10))
ax = pl.subplot(2,1,1, adjustable='box', aspect=0.88)

crds = basetable['skycoord_f410m']
sel = basetable['sep_f405n'].quantity < 0.1*u.arcsec
sel &= (~any_saturated) & (any_good)
#sel &= basetable['mag_ab_f410m'] < 18.5
sel &= basetable['mag_ab_f405n'] - basetable['mag_ab_f444w'] < -2
xx,yy = ww410.world_to_pixel(crds[sel])

colorby = basetable['mag_ab_f182m'] - basetable['mag_ab_f410m']
colorby = basetable['mag_ab_f410m']
colorby = basetable['mag_ab_f444w']

colornorm = simple_norm(colorby[sel], stretch='linear')
cmap = 'YlOrRd'

scat = ax.scatter(
                  crds.dec[sel],
                  crds.ra[sel],
                  c=colorby[sel],
                  s=3.5,
                  alpha=1,
                  norm=colornorm,
                  cmap=cmap)

pl.draw()
colors = scat.get_facecolors()
scat.set_edgecolors(colors)
scat.set_facecolors('none')
ax.axis()
ax.set_ylabel("Right Ascension [ICRS]")
ax.set_xlabel("Declination [ICRS]");

# %%
pl.figure(figsize=(20,10))
ax = pl.subplot(2,1,1, adjustable='box', aspect=0.88)
ax2 = pl.subplot(2,1,2, adjustable='box', aspect=0.88)

crds = basetable['skycoord_f410m']
sel = basetable['sep_f405n'].quantity < 0.1*u.arcsec
sel &= (~any_saturated) & (any_good)
#sel &= basetable['mag_ab_f410m'] < 18.5
colsel = basetable['mag_ab_f405n'] - basetable['mag_ab_f444w'] < -2
sel &= colsel
xx,yy = ww410.world_to_pixel(crds[sel])

colorby = basetable['mag_ab_f182m'] - basetable['mag_ab_f410m']
colorby = basetable['mag_ab_f410m']
colorby = basetable['mag_ab_f444w']

colornorm = simple_norm(colorby[sel], stretch='linear')
cmap = 'YlOrRd'

scat = ax.scatter(
                  crds.dec[sel],
                  crds.ra[sel],
                  c=colorby[sel],
                  s=3.5,
                  alpha=1,
                  norm=colornorm,
                  cmap=cmap)

pl.draw()
colors = scat.get_facecolors()
scat.set_edgecolors(colors)
scat.set_facecolors('none')
ax.axis()
ax.set_ylabel("Right Ascension [ICRS]")
ax.set_xlabel("Declination [ICRS]");

sel2 = basetable['sep_f405n'].quantity < 0.1*u.arcsec
sel2 &= (~any_saturated) & (any_good)
sel2 &= ~colsel
scat = ax2.scatter(
                  crds.dec[sel2],
                  crds.ra[sel2],
                  c=colorby[sel2],
                  s=0.5,
                  alpha=0.75,
                  norm=colornorm,
                  cmap=cmap)

# %%
pl.figure(figsize=(20,10))
ax = pl.subplot(2,1,1, adjustable='box', aspect=0.88)
ax2 = pl.subplot(2,1,2, adjustable='box', aspect=0.88)

crds = basetable['skycoord_f410m']
sel = basetable['sep_f405n'].quantity < 0.1*u.arcsec
sel &= (~any_saturated) & (any_good)
#sel &= basetable['mag_ab_f410m'] < 18.5
colsel = (basetable['mag_ab_f187n'] - basetable['mag_ab_f182m'] < -1) & (basetable['mag_ab_f405n'] - basetable['mag_ab_f410m'] < 0)
sel &= colsel
xx,yy = ww410.world_to_pixel(crds[sel])

colorby = basetable['mag_ab_f182m'] - basetable['mag_ab_f410m']
colorby = basetable['mag_ab_f410m']
colorby = basetable['mag_ab_f212n']

colornorm = simple_norm(colorby[sel], stretch='linear')
cmap = 'YlOrRd'

scat = ax.scatter(
                  crds.dec[sel],
                  crds.ra[sel],
                  c=colorby[sel],
                  s=3.5,
                  alpha=1,
                  norm=colornorm,
                  cmap=cmap)

pl.draw()
colors = scat.get_facecolors()
scat.set_edgecolors(colors)
scat.set_facecolors('none')
ax.axis()
ax.set_ylabel("Right Ascension [ICRS]")
ax.set_xlabel("Declination [ICRS]");

sel2 = basetable['sep_f405n'].quantity < 0.1*u.arcsec
sel2 &= (~any_saturated) & (any_good)
sel2 &= ~colsel
scat = ax2.scatter(
                  crds.dec[sel2],
                  crds.ra[sel2],
                  c=colorby[sel2],
                  s=0.5,
                  alpha=0.75,
                  norm=colornorm,
                  cmap=cmap)
